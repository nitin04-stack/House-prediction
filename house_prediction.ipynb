# %%
import pandas as pd

# %%
df = pd.read_csv("HousePricePrediction (1).csv")

# %%
df.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 2166  2166          20       RL     8696    Inside     1Fam            5
# 1945  1945          20       RL    31220       FR2     1Fam            2
# 155    155          50       RL     9600    Corner     1Fam            5
# 2564  2564          20       RL    13108    Inside     1Fam            5
# 2896  2896          20       RL    23580    Inside     1Fam            6
# 2435  2435          20       RL     7000    Corner     1Fam            6
# 2885  2885          60       RL    15600    Inside     1Fam            7
# 1623  1623          60       RL    12961    Inside     1Fam            5
# 1243  1243          20       RL    13891    Inside     1Fam            5
# 455    455          20       RL     9600    Inside     1Fam            6
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 2166       1997          1998     VinylSd         0.0       1418.0        NaN
# 1945       1952          1952     BrkFace         0.0       1632.0        NaN
# 155        1924          1950     Wd Sdng         0.0        572.0    79000.0
# 2564       1951          1951     Wd Sdng         0.0          0.0        NaN
# 2896       1979          1979     Plywood         0.0       1625.0        NaN
# 2435       1961          1961     BrkFace         0.0          0.0        NaN
# 2885       1950          1963     Wd Sdng         0.0       1168.0        NaN
# 1623       1993          1994     VinylSd         0.0       1152.0        NaN
# 1243       2006          2006     VinylSd         0.0       2076.0   465000.0
# 455        1973          1973     HdBoard         0.0       1242.0   175500.0

# %%
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotArea            0
# LotConfig          0
# BldgType           0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# Exterior1st        1
# BsmtFinSF2         1
# TotalBsmtSF        1
# SalePrice       1459
# dtype: int64

# %%
df["SalePrice"] = df["SalePrice"].fillna(df["SalePrice"].mean())

# %%
df.isnull().sum()
# Out:
# Id              0
# MSSubClass      0
# MSZoning        4
# LotArea         0
# LotConfig       0
# BldgType        0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# Exterior1st     1
# BsmtFinSF2      1
# TotalBsmtSF     1
# SalePrice       0
# dtype: int64

# %%
df.dropna()
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  \
# 0          2003          2003     VinylSd         0.0        856.0
# 1          1976          1976     MetalSd         0.0       1262.0
# 2          2001          2002     VinylSd         0.0        920.0
# 3          1915          1970     Wd Sdng         0.0        756.0
# 4          2000          2000     VinylSd         0.0       1145.0
# ...         ...           ...         ...         ...          ...
# 2914       1970          1970     CemntBd         0.0        546.0
# 2915       1970          1970     CemntBd         0.0        546.0
# 2916       1960          1996     VinylSd         0.0       1224.0
# 2917       1992          1992     HdBoard         0.0        912.0
# 2918       1993          1994     HdBoard         0.0        996.0
#
#          SalePrice
# 0     208500.00000
# 1     181500.00000
# 2     223500.00000
# 3     140000.00000
# 4     250000.00000
# ...            ...
# 2914  180921.19589
# 2915  180921.19589
# 2916  180921.19589
# 2917  180921.19589
# 2918  180921.19589
#
# [2913 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Id              0
# MSSubClass      0
# MSZoning        4
# LotArea         0
# LotConfig       0
# BldgType        0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# Exterior1st     1
# BsmtFinSF2      1
# TotalBsmtSF     1
# SalePrice       0
# dtype: int64

# %%
df["MSZoning"].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH', nan], dtype=object)

# %%
cols = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
df = pd.get_dummies(df , columns = cols , drop_first = True,dtype = int)

# %%
df.isnull().sum()
# Out:
# Id                     0
# MSSubClass             0
# LotArea                0
# OverallCond            0
# YearBuilt              0
# YearRemodAdd           0
# BsmtFinSF2             1
# TotalBsmtSF            1
# SalePrice              0
# MSZoning_FV            0
# MSZoning_RH            0
# MSZoning_RL            0
# MSZoning_RM            0
# LotConfig_CulDSac      0
# LotConfig_FR2          0
# LotConfig_FR3          0
# LotConfig_Inside       0
# BldgType_2fmCon        0
# BldgType_Duplex        0
# BldgType_Twnhs         0
# BldgType_TwnhsE        0
# Exterior1st_AsphShn    0
# Exterior1st_BrkComm    0
# Exterior1st_BrkFace    0
# Exterior1st_CBlock     0
# Exterior1st_CemntBd    0
# Exterior1st_HdBoard    0
# Exterior1st_ImStucc    0
# Exterior1st_MetalSd    0
# Exterior1st_Plywood    0
# Exterior1st_Stone      0
# Exterior1st_Stucco     0
# Exterior1st_VinylSd    0
# Exterior1st_Wd Sdng    0
# Exterior1st_WdShing    0
# dtype: int64

# %%
df["BsmtFinSF2"] = df["BsmtFinSF2"].fillna(0)
df["BsmtFinSF2"] =  df["BsmtFinSF2"].astype("int64")

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df["TotalBsmtSF"] = df["TotalBsmtSF"].fillna(0)
df["TotalBsmtSF"] =  df["TotalBsmtSF"].astype("int64")

# %%
df = df.drop("Id",axis = 1)

# %%
df.sample(10)
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 2352          60    10625            5       2004          2004           0
# 155           50     9600            5       1924          1950           0
# 379           60     8123            5       2000          2000           0
# 118           60    12376            5       1990          1990           0
# 2561          70     6720            7       1921          1950           0
# 1077          20    15870            5       1969          1969         791
# 2231          20    12890            5       1989          1989           0
# 1481         120     7132            5       2006          2006           0
# 44            20     7945            6       1959          1959         506
# 2554          40    10042            8       1920          1995         278
#
#       TotalBsmtSF     SalePrice  MSZoning_FV  MSZoning_RH  ...  \
# 2352         1158  180921.19589            1            0  ...
# 155           572   79000.00000            0            0  ...
# 379           982  179000.00000            0            0  ...
# 118          1673  320000.00000            0            0  ...
# 2561          585  180921.19589            0            0  ...
# 1077         1096  138800.00000            0            0  ...
# 2231         1495  180921.19589            0            0  ...
# 1481         1370  180921.19589            0            0  ...
# 44           1150  141000.00000            0            0  ...
# 2554          660  180921.19589            0            0  ...
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 2352                    0                    0                    0
# 155                     0                    0                    0
# 379                     0                    0                    0
# 118                     0                    0                    0
# 2561                    0                    0                    0
# 1077                    0                    0                    0
# 2231                    0                    0                    0
# 1481                    0                    0                    0
# 44                      0                    0                    0
# 2554                    0                    0                    0
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 2352                    0                    0                  0
# 155                     0                    0                  0
# 379                     0                    0                  0
# 118                     0                    1                  0
# 2561                    0                    0                  0
# 1077                    0                    0                  0
# 2231                    0                    0                  0
# 1481                    0                    0                  0
# 44                      0                    0                  0
# 2554                    0                    0                  0
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 2352                   0                    1                    0
# 155                    0                    0                    1
# 379                    0                    1                    0
# 118                    0                    0                    0
# 2561                   0                    1                    0
# 1077                   0                    1                    0
# 2231                   0                    0                    1
# 1481                   0                    1                    0
# 44                     0                    0                    0
# 2554                   0                    0                    1
#
#       Exterior1st_WdShing
# 2352                    0
# 155                     0
# 379                     0
# 118                     0
# 2561                    0
# 1077                    0
# 2231                    0
# 1481                    0
# 44                      0
# 2554                    0
#
# [10 rows x 34 columns]

# %%
x = df.drop("SalePrice",axis = 1)
y = df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train.head()
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 2650         160     2179            5       1976          1976           0
# 1709          20     7500            5       2006          2007           0
# 869           60     9938            5       1993          1994           0
# 2355          20    12450            5       2003          2004           0
# 2914         160     1936            7       1970          1970           0
#
#       TotalBsmtSF  MSZoning_FV  MSZoning_RH  MSZoning_RL  ...  \
# 2650          855            0            0            1  ...
# 1709         1372            1            0            0  ...
# 869          1050            0            0            1  ...
# 2355         1094            0            0            1  ...
# 2914          546            0            0            0  ...
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 2650                    0                    0                    0
# 1709                    0                    0                    0
# 869                     0                    0                    0
# 2355                    0                    0                    0
# 2914                    1                    0                    0
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 2650                    0                    1                  0
# 1709                    0                    0                  0
# 869                     1                    0                  0
# 2355                    0                    0                  0
# 2914                    0                    0                  0
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 2650                   0                    0                    0
# 1709                   0                    1                    0
# 869                    0                    0                    0
# 2355                   0                    1                    0
# 2914                   0                    0                    0
#
#       Exterior1st_WdShing
# 2650                    0
# 1709                    0
# 869                     0
# 2355                    0
# 2914                    0
#
# [5 rows x 33 columns]

# %%
y_train.head()
# Out:
# 2650    180921.19589
# 1709    180921.19589
# 869     236000.00000
# 2355    180921.19589
# 2914    180921.19589
# Name: SalePrice, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.33632812995189476

# %%
# Out:
# accuracy: 2437    1.070925
# 2470    0.972107
# 2359    1.183117
# 789     0.997627
# 1642    0.894312
#           ...
# 2880    1.139411
# 2295    0.769082
# 2222    0.776852
# 1090    0.782663
# 542     1.075820
# Name: SalePrice, Length: 584, dtype: float64
