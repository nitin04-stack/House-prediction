# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , precision_score,recall_score,f1_score
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("loan_approval_data (1).csv")

# %%
df.sample(10)
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 356         357.0           11435.0              7266.0          Salaried
# 355           NaN            9253.0                 NaN     Self-employed
# 170         171.0            4811.0              3241.0          Salaried
# 618         619.0            7569.0              9400.0          Salaried
# 933         934.0            4717.0              7179.0          Contract
# 957         958.0           12998.0              1179.0     Self-employed
# 225         226.0            3218.0              6402.0          Salaried
# 774         775.0               NaN              6807.0          Salaried
# 24            NaN            3899.0              8232.0        Unemployed
# 530           NaN            8042.0              9989.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 356  30.0        Married         2.0         698.0             0.0       0.54
# 355  44.0        Married         1.0         728.0             1.0       0.22
# 170  43.0         Single         0.0         749.0             1.0       0.47
# 618  35.0         Single         1.0         743.0             0.0       0.43
# 933  48.0         Single         2.0         751.0             1.0       0.23
# 957  33.0        Married         3.0         767.0             0.0       0.55
# 225  44.0        Married         NaN         783.0             NaN       0.39
# 774  50.0        Married         3.0         786.0             1.0       0.40
# 24   26.0         Single         3.0         778.0             NaN       0.38
# 530  37.0        Married         NaN         576.0             4.0       0.44
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 356   4354.0           40318.0      19242.0       60.0    Education
# 355   5266.0           41190.0       7579.0        NaN          Car
# 170   4184.0             246.0      27562.0       12.0     Personal
# 618   1550.0           44132.0      34077.0       72.0          Car
# 933    562.0               NaN      14715.0       60.0         Home
# 957   6044.0           18013.0      39278.0       12.0     Personal
# 225  13824.0           10482.0       4465.0       60.0     Personal
# 774   5154.0            6766.0      26685.0       84.0    Education
# 24   18722.0           44324.0      33305.0       72.0         Home
# 530  19541.0           19043.0      28066.0       60.0          Car
#
#     Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 356         Urban        Graduate    Male           Private            No
# 355         Urban        Graduate    Male               NaN           Yes
# 170         Urban    Not Graduate    Male               MNC            No
# 618     Semiurban    Not Graduate    Male           Private            No
# 933     Semiurban             NaN    Male           Private           Yes
# 957         Rural        Graduate    Male           Private            No
# 225         Urban        Graduate  Female          Business           Yes
# 774         Rural        Graduate  Female               MNC            No
# 24          Urban        Graduate  Female        Government            No
# 530         Urban        Graduate  Female               NaN            No

# %%
df.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status     50
# Age                   50
# Marital_Status        50
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose          50
# Property_Area         50
# Education_Level       50
# Gender                50
# Employer_Category     50
# Loan_Approved         50
# dtype: int64

# %%
df.dropna()
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0             1.0           17795.0              1387.0          Salaried
# 3             4.0           13964.0              8173.0          Salaried
# 5             6.0            8265.0              4831.0          Salaried
# 6             7.0           18850.0              2768.0          Salaried
# 10           11.0           18023.0              4033.0          Salaried
# ..            ...               ...                 ...               ...
# 985         986.0           10705.0              7898.0          Salaried
# 987         988.0            6841.0              2293.0     Self-employed
# 993         994.0           16596.0              6007.0     Self-employed
# 997         998.0           15192.0              8433.0          Contract
# 998         999.0            9083.0              7380.0        Unemployed
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0    51.0        Married         0.0         637.0             4.0       0.53
# 3    40.0        Married         2.0         579.0             3.0       0.31
# 5    53.0         Single         1.0         602.0             1.0       0.56
# 6    58.0        Married         0.0         687.0             0.0       0.48
# 10   52.0        Married         2.0         688.0             1.0       0.13
# ..    ...            ...         ...           ...             ...        ...
# 985  33.0         Single         1.0         704.0             4.0       0.55
# 987  34.0        Married         2.0         639.0             2.0       0.22
# 993  33.0        Married         2.0         688.0             4.0       0.21
# 997  48.0         Single         1.0         666.0             1.0       0.40
# 998  50.0         Single         1.0         748.0             3.0       0.31
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0    19403.0           45638.0      16619.0       84.0     Personal
# 3     9553.0           10844.0      27819.0       60.0     Business
# 5    19522.0            2911.0       9798.0       36.0         Home
# 6    14635.0            8991.0      26143.0       24.0         Home
# 10   18244.0           40004.0      10415.0       12.0    Education
# ..       ...               ...          ...        ...          ...
# 985    569.0            2654.0      11524.0       84.0         Home
# 987   2822.0           24204.0      27673.0       36.0          Car
# 993   1257.0           16206.0      35329.0       24.0         Home
# 997   8581.0           41335.0      16203.0       24.0         Home
# 998  13491.0            8933.0      10290.0       36.0     Personal
#
#     Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0           Urban    Not Graduate  Female           Private            No
# 3           Rural        Graduate  Female        Government            No
# 5       Semiurban        Graduate    Male        Unemployed            No
# 6           Rural        Graduate    Male           Private            No
# 10          Urban    Not Graduate  Female               MNC           Yes
# ..            ...             ...     ...               ...           ...
# 985         Rural        Graduate  Female           Private            No
# 987     Semiurban        Graduate    Male           Private            No
# 993         Rural        Graduate    Male        Government           Yes
# 997         Rural        Graduate    Male               MNC            No
# 998         Urban        Graduate    Male           Private           Yes
#
# [351 rows x 20 columns]

# %%
df.shape
# Out:
# (1000, 20)

# %%
catagorical_values = df.select_dtypes(include = ["float34"]).columns
