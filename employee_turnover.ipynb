# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score

# %%
df = pd.read_csv("employee_turnover (1).csv")

# %%
df.isnull().sum()
# Out:
# Job_Satisfaction                           0
# Performance_Rating                         0
# Years_At_Company                           0
# Work_Life_Balance                          0
# Distance_From_Home                         0
# Monthly_Income                             0
# Education_Level                            0
# Age                                        0
# Num_Companies_Worked                       0
# Employee_Role                              0
# Annual_Bonus                               0
# Training_Hours                             0
# Department                                 0
# Annual_Bonus_Squared                       0
# Annual_Bonus_Training_Hours_Interaction    0
# Employee_Turnover                          0
# dtype: int64

# %%
df.sample(10)
# Out:
#       Job_Satisfaction  Performance_Rating  Years_At_Company  \
# 385           0.548051            0.654220          0.222085
# 519           0.556789            0.502917          0.447999
# 149           0.900675            0.769872          0.849690
# 882           0.279945            0.040634          0.677203
# 805           0.334544            0.906855          0.079356
# 826           0.272958            0.499621          0.332074
# 54            0.843537            0.850203          0.825390
# 605           0.188519            0.203412          0.957575
# 649           0.311796            0.696343          0.377752
# 1032          0.231758            0.004239          0.499174
#
#       Work_Life_Balance  Distance_From_Home  Monthly_Income  Education_Level  \
# 385            0.919127            0.859736        0.787143         0.025481
# 519            0.744502            0.550318        0.119326         0.069458
# 149            0.032945            0.310195        0.515433         0.415953
# 882            0.142591            0.459348        0.666755         0.891294
# 805            0.764817            0.489711        0.637433         0.587824
# 826            0.510438            0.229364        0.198060         0.733998
# 54             0.388975            0.582497        0.554663         0.750455
# 605            0.130215            0.714165        0.895152         0.432612
# 649            0.179604            0.024679        0.067250         0.679393
# 1032           0.356437            0.427119        0.573342         0.076050
#
#            Age  Num_Companies_Worked  Employee_Role  Annual_Bonus  \
# 385   0.194527              0.916697       0.809054      0.846160
# 519   0.267873              0.973264       0.081673      0.537990
# 149   0.231255              0.307874       0.945431      0.294181
# 882   0.609364              0.217725       0.474056      0.667620
# 805   0.530259              0.698347       0.545706      0.922472
# 826   0.385728              0.232566       0.858420      0.401700
# 54    0.982461              0.060850       0.789569      0.417831
# 605   0.759691              0.812493       0.452634      0.764432
# 649   0.453697              0.536579       0.896671      0.990339
# 1032  0.262791              0.230016       0.886328      0.741239
#
#       Training_Hours  Department  Annual_Bonus_Squared  \
# 385         0.404570    0.256375              0.715986
# 519         0.920859    0.076856              0.289434
# 149         0.353904    0.003710              0.086542
# 882         0.195318    0.732172              0.445717
# 805         0.551678    0.919666              0.850954
# 826         0.115870    0.708048              0.161363
# 54          0.375180    0.593317              0.174583
# 605         0.014787    0.160985              0.584356
# 649         0.216897    0.663078              0.980771
# 1032        0.185894    0.838349              0.549436
#
#       Annual_Bonus_Training_Hours_Interaction  Employee_Turnover
# 385                                  0.342330                  1
# 519                                  0.495413                  1
# 149                                  0.104112                  1
# 882                                  0.130398                  0
# 805                                  0.508907                  1
# 826                                  0.046545                  0
# 54                                   0.156762                  1
# 605                                  0.011303                  0
# 649                                  0.214802                  0
# 1032                                 0.137792                  0

# %%
x = df.drop("Employee_Turnover",axis = 1)
y = df["Employee_Turnover"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8592592592592593

# %%
precision_score(y_test,y_pred)
# Out:
# 0.8717948717948718

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso()

# %%
model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import  mean_squared_error,classification_report

# %%
 mean_squared_error(y_test,y_pred)
# Out:
# 0.2505221193415638
